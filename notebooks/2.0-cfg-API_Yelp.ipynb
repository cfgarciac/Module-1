# %% [markdown]
# # Avance 2 — Integración con Yelp Fusion API (Miami)
#
# ## Proyecto: Conociendo al Cliente 360°
# **Autor:** Cristian Fernando García Cadena
# **Fecha:** 23 de Octubre de 2025
#
# ## Objetivo
# Conectar a la **Yelp Fusion API**, extraer una muestra representativa de negocios **“restaurants”** para la ciudad seleccionada en el Avance 1 (**Miami**), normalizar los datos a formato tabular y **enriquecer** la base de clientes con **KPI por ciudad** (número de negocios, rating promedio y categoría predominante).
# El foco es **técnico y reproducible**: autenticación, requests, transformación JSON→pandas y merge controlado con el dataset interno.
#
# ---
#
# ## Contexto (desde el Avance 1)
# - Se eligió **Miami** por volumen de clientes y señales favorables (gasto y tasa premium).
# - Contamos con la base limpia `data/processed/base_clientes_clean.csv`.
# - En este avance incorporamos **información externa** (Yelp) para sumar **contexto local** de oferta gastronómica.
#
# ---
#
# ## Entradas y salidas
#
# **Entradas**
# - API: `https://api.yelp.com/v3/businesses/search` (parámetros: `term=restaurants`, `location=Miami`, `limit=50`).
# - Dataset interno: `data/processed/base_clientes_clean.csv` (clientes).
#
# **Salidas**
# - **Cache crudo** de la respuesta: `data/external/yelp_raw/miami_p0.json`
#   (evita gastar llamadas durante el desarrollo).
# - **Tabla procesada Yelp**: `data/processed/yelp_businesses_miami.csv`.
# - **Base enriquecida por persona**: `data/processed/base_clientes_clean_enriched.csv`
#   (agrega: `yelp_n_businesses`, `yelp_avg_rating`, `yelp_top_category`).
# - **Notebook de entrega:** `Avance_2_API_Yelp.ipynb`
# - **Dataset intermedio enriquecido:** `data/processed/base_clientes_clean_enriched.csv`
#
# ---

# %%
import pandas as pd
import requests
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# URL de la API
api_url = 'https://api.yelp.com/v3/businesses/search'

# Datos de autenticación de la cuenta de usuario creada previamente
clientid = 'GWOCZh9-BmZxtdsAjr7Gug'
apikey = 'FHVvXoNmTXIl9DuxYis7AV5uLPujm9MLwrhgs5NgvCfaOxd3V6mxt6dQU8eEqYJiGxe816XATx7ufWjbMWqbV-2Uku1jxBJv8BGRC74NroLPl27PDQqs0tDixit-YHYx'

# Cabecera requerida para autenticar la solicitud
headers = {'Authorization': 'Bearer %s' % apikey}

# Ciudad seleccionada (puede venir del dataset del Avance 1)
ciudad = "Miami"

# Consulta de restaurantes en la ciudad
params = {'term': 'restaurants', 'location': ciudad, 'limit': 50}
response = requests.get(api_url, params=params, headers=headers)

# Conversión de la respuesta JSON a diccionario
data = response.json()
data
# Out:
# {'businesses': [{'id': 'K3ukx2e11xTRtYBU01dmrA',
#    'alias': 'salty-flame-miami',
#    'name': 'Salty Flame',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/_6wShTvzfucB5dxFZv4Mpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salty-flame-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 212,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.76022, 'longitude': -80.19267},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1414 Brickell Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33131',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1414 Brickell Ave', 'Miami, FL 33131']},
#    'phone': '+13055638972',
#    'display_phone': '(305) 563-8972',
#    'distance': 9568.050891007853},
#   {'id': 'oxtMfBGmVNE18pFVuw7lFg',
#    'alias': 'fratellino-coral-gables-2',
#    'name': 'Fratellino',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/OPS9ibIzgVyzcJ3ZyNf9IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fratellino-coral-gables-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1827,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 25.74917, 'longitude': -80.26011},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '264 Miracle Mile',
#     'address2': '',
#     'address3': '',
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['264 Miracle Mile', 'Coral Gables, FL 33134']},
#    'phone': '+17864520068',
#    'display_phone': '(786) 452-0068',
#    'distance': 2834.064936518243},
#   {'id': 'UXHxLN3DcDGI57uDIfCuJA',
#    'alias': 'olds-havana-cuban-bar-and-cocina-miami',
#    'name': "Old's Havana Cuban Bar & Cocina",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/OyMD-xvBjobfDmDdBs2Jfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olds-havana-cuban-bar-and-cocina-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 3041,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.7655942148975,
#     'longitude': -80.2192383373502},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1442 SW 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33135',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1442 SW 8th St', 'Miami, FL 33135']},
#    'phone': '+17865182196',
#    'display_phone': '(786) 518-2196',
#    'distance': 7035.905419577772},
#   {'id': 'ix8ifP1jQM9ektdVAs19sQ',
#    'alias': 'crazy-about-you-miami-3',
#    'name': 'Crazy About You',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/vvQBoPHlEO5bi5fbmM1B3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crazy-about-you-miami-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 2807,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.762015277335745,
#     'longitude': -80.1889859201474},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1155 Brickell Bay Dr',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33131',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1155 Brickell Bay Dr', 'Ste 101', 'Miami, FL 33131']},
#    'phone': '+13053774442',
#    'display_phone': '(305) 377-4442',
#    'distance': 9973.468955482575},
#   {'id': 'WqIBKxRUPXH3NqTViAHLxQ',
#    'alias': 'bayshore-club-bar-and-grill-miami',
#    'name': 'Bayshore Club Bar & Grill',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/B7tTbJMlp7Dk6rpE4P3j5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bayshore-club-bar-and-grill-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 965,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.72877375829567, 'longitude': -80.2341624},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '3391 Pan American Dr',
#     'address2': None,
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33133',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3391 Pan American Dr', 'Miami, FL 33133']},
#    'phone': '+13052091200',
#    'display_phone': '(305) 209-1200',
#    'distance': 6023.917796785677},
#   {'id': 'eVhl0Yu1ZRWRD2D1OQGsYg',
#    'alias': 'capriccio-blue-lagoon-miami',
#    'name': 'Capriccio Blue Lagoon',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/XvLWJxAVk_KVc2Ucr5Lh9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/capriccio-blue-lagoon-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 136,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.78146011787451,
#     'longitude': -80.28785769999999},
#    'transactions': [],
#    'location': {'address1': '5600 Blue Lagoon Dr',
#     'address2': 'Ste 9',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33126',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['5600 Blue Lagoon Dr', 'Ste 9', 'Miami, FL 33126']},
#    'phone': '+17869365470',
#    'display_phone': '(786) 936-5470',
#    'distance': 3183.705118041825},
#   {'id': '_tiVacKyfWZjOljFenLwVQ',
#    'alias': 'giselle-miami-miami',
#    'name': 'Giselle Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/tMrFekA5lavl0IHHuyVwHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giselle-miami-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 454,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.78496366, 'longitude': -80.19341399},
#    'transactions': [],
#    'location': {'address1': '15 NE 11th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['15 NE 11th St', 'Miami, FL 33132']},
#    'phone': '+13053589848',
#    'display_phone': '(305) 358-9848',
#    'distance': 10127.920790439312},
#   {'id': 'z1UW-zeI50bMEtGKFtrjmA',
#    'alias': 'grails-miami-restaurant-and-sports-bar-miami',
#    'name': 'Grails Miami - Restaurant & Sports Bar',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Fl1nu1i2Q88gWHR58REV6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grails-miami-restaurant-and-sports-bar-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 728,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.803184, 'longitude': -80.195219},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2800 N Miami Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33127',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2800 N Miami Ave', 'Miami, FL 33127']},
#    'phone': '+17868704313',
#    'display_phone': '(786) 870-4313',
#    'distance': 10852.71572211731},
#   {'id': 'O4gh_gZPp1zW9QtC1aMHWw',
#    'alias': 'house-of-food-porn-miami-3',
#    'name': 'House of Food Porn',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/aPuAIRjMLKqEsNlYbcbdCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-food-porn-miami-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 171,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 25.8326319884545,
#     'longitude': -80.200107379434},
#    'transactions': [],
#    'location': {'address1': '197 NW 62nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33150',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['197 NW 62nd St', 'Miami, FL 33150']},
#    'phone': '+13057880137',
#    'display_phone': '(305) 788-0137',
#    'distance': 12507.730930037038},
#   {'id': 'Obt7Njta79-1CNtNwhNXiw',
#    'alias': 'bunbury-miami-3',
#    'name': 'Bunbury',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/uW2ngKV5uCi1mK3QWsv8wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunbury-miami-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 954,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.788458, 'longitude': -80.193363},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '55 NE 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['55 NE 14th St', 'Miami, FL 33132']},
#    'phone': '+13053336929',
#    'display_phone': '(305) 333-6929',
#    'distance': 10276.024248591662},
#   {'id': 'hZm7TunlrksQbgS0ssXbUg',
#    'alias': 'versailles-miami-4',
#    'name': 'Versailles',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/q_T1_ShhFe0CuPaNtvzLXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/versailles-miami-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 6912,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.765389817507295,
#     'longitude': -80.25287416592283},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3555 SW 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33135',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3555 SW 8th St', 'Miami, FL 33135']},
#    'phone': '+13054440240',
#    'display_phone': '(305) 444-0240',
#    'distance': 3789.5569842271616},
#   {'id': '4GKmQ1rynV5RUSiaHHenWQ',
#    'alias': 'first-watch-miami-6',
#    'name': 'First Watch',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/FGplZZ2oiPsrlkSl-IvwLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/first-watch-miami-6?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 505,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tradamerican', 'title': 'American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.77831, 'longitude': -80.29053},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5799 NW 7th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33125',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['5799 NW 7th St', 'Miami, FL 33125']},
#    'phone': '+17866055050',
#    'display_phone': '(786) 605-5050',
#    'distance': 2844.225718190066},
#   {'id': 'OwF4aaSHwwhLRYmx270qoQ',
#    'alias': 'tacos-el-carnal-miami',
#    'name': 'Tacos El Carnal',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/9XRI60hN-HcnITOFMj5J7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-carnal-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 327,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.76231, 'longitude': -80.29583},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '6888 W Flagler St',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33144',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['6888 W Flagler St', 'Miami, FL 33144']},
#    'phone': '+13053920830',
#    'display_phone': '(305) 392-0830',
#    'distance': 2731.297250589728},
#   {'id': '1h8-r9cLeXxW99HhlRUnlA',
#    'alias': 'cvi-che-105-miami',
#    'name': 'CVI.CHE 105',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ZpOnQ-Le1zrwvqNt-svioA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cvi-che-105-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 5993,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.775383, 'longitude': -80.1884004},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '105 NE 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['105 NE 3rd Ave', 'Miami, FL 33132']},
#    'phone': '+13055773454',
#    'display_phone': '(305) 577-3454',
#    'distance': 10289.40979151124},
#   {'id': 'QQnw1bFxLyamuxn4giIy9g',
#    'alias': 'sufrat-mediterranean-grill-miami-4',
#    'name': 'Sufrat Mediterranean Grill',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Z5Q7D855uiOO8WKuDn-eGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sufrat-mediterranean-grill-miami-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 127,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.82001, 'longitude': -80.335628},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8455 NW 53rd St',
#     'address2': 'Suite 106',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33166',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['8455 NW 53rd St', 'Suite 106', 'Miami, FL 33166']},
#    'phone': '+13057987278',
#    'display_phone': '(305) 798-7278',
#    'distance': 8884.862194544405},
#   {'id': 'oiFJpaLxJYO0WzSEhYWmJg',
#    'alias': 'china-spot-miami-miami-2',
#    'name': 'China Spot Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/EW--orGRTd_blT9I8JaKAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-spot-miami-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 25.79501109, 'longitude': -80.19422326},
#    'transactions': [],
#    'location': {'address1': '1900 NE Miami Ct',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1900 NE Miami Ct', 'Miami, FL 33132']},
#    'phone': '+17865708743',
#    'display_phone': '(786) 570-8743',
#    'distance': 10500.965895559915},
#   {'id': 'Q9Xq-w4DhTeGA_csODsMCA',
#    'alias': 'loretta-and-the-butcher-miami',
#    'name': 'Loretta & The Butcher',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/iq1HMGTlCxtgWL5TpfzwDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loretta-and-the-butcher-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 317,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.727761, 'longitude': -80.2445689},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '3195 Commodore Plz',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33133',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3195 Commodore Plz', 'Miami, FL 33133']},
#    'phone': '+17866189982',
#    'display_phone': '(786) 618-9982',
#    'distance': 5170.824888266938},
#   {'id': '0EVWp_KyFdWC9VxJ7Sku1Q',
#    'alias': 'cote-miami-miami-2',
#    'name': 'COTE Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/rdK1JuhS_SRzZJipgwMZRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cote-miami-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 943,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.812905772091284,
#     'longitude': -80.19149139999999},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '3900 NE 2nd Ave',
#     'address2': None,
#     'address3': 'Miami Design District',
#     'city': 'Miami',
#     'zip_code': '33137',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3900 NE 2nd Ave',
#      'Miami Design District',
#      'Miami, FL 33137']},
#    'phone': '+13054344668',
#    'display_phone': '(305) 434-4668',
#    'distance': 11751.444187202473},
#   {'id': 'scZfLg-ujWMEOUmFM_Qalg',
#    'alias': 'don-maguey-mexican-restaurant-miami',
#    'name': 'Don Maguey Mexican Restaurant',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/_FLDwm67guwt-yv3rqzXLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-maguey-mexican-restaurant-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 265,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.7717682877048,
#     'longitude': -80.27253760250089},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '4747 W Flagler St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['4747 W Flagler St', 'Miami, FL 33134']},
#    'phone': '+17865585650',
#    'display_phone': '(786) 558-5650',
#    'distance': 2616.9735888249156},
#   {'id': 'yxPn5n5se97lnNYN5JcAIw',
#    'alias': 'le-chick-miami-2',
#    'name': 'Le Chick',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/uRlgz996l8A4_2w279pNig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-chick-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1426,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.79989504, 'longitude': -80.20052197},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '310 NW 24th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33127',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['310 NW 24th St', 'Miami, FL 33127']},
#    'phone': '+17862167086',
#    'display_phone': '(786) 216-7086',
#    'distance': 10207.989856355258},
#   {'id': 'gmDna9f57vWTlSrdrEuVEg',
#    'alias': 'sanguich-miami',
#    'name': 'Sanguich',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/GSYOfiVblSDf68U0wtDsEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sanguich-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1429,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.76578005893393, 'longitude': -80.2285558},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2057 SW 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33135',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2057 SW 8th St', 'Miami, FL 33135']},
#    'phone': '+13055390969',
#    'display_phone': '(305) 539-0969',
#    'distance': 6129.703156662285},
#   {'id': 'jp8y_UlQW8KE0yAcJ1Jubg',
#    'alias': 'the-fatty-crab-doral-2',
#    'name': 'The Fatty Crab',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/5Wex_U5qaJE6_88WJ0Oarg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fatty-crab-doral-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 738,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.7932394, 'longitude': -80.3379343},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2000 NW 87th Ave',
#     'address2': 'Ste 7',
#     'address3': None,
#     'city': 'Doral',
#     'zip_code': '33172',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2000 NW 87th Ave', 'Ste 7', 'Doral, FL 33172']},
#    'phone': '+17866185183',
#    'display_phone': '(786) 618-5183',
#    'distance': 6718.716350078568},
#   {'id': 'JnWk31PtaDGD3JfO9eyVkw',
#    'alias': 'impressions-miami',
#    'name': 'Impressions',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/3YWL3sCTPiHpz7FqOB9aAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/impressions-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.7783409549632,
#     'longitude': -80.3094483911991},
#    'transactions': [],
#    'location': {'address1': '711 NW 72nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33126',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['711 NW 72nd Ave', 'Miami, FL 33126']},
#    'phone': '+13052613800',
#    'display_phone': '(305) 261-3800',
#    'distance': 3555.120501416882},
#   {'id': 'nwY3CmIH75cN85cWBSaOAw',
#    'alias': 'apocalypse-bbq-miami',
#    'name': 'Apocalypse BBQ',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/dnWRHDwSOApEyxPoZZRFLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apocalypse-bbq-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 961,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.687992898443856,
#     'longitude': -80.39359629851486},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8695 SW 124th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33183',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['8695 SW 124th Ave', 'Miami, FL 33183']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 12797.303415150403},
#   {'id': 'Jjifi324EdbrMWSW2-ZcKQ',
#    'alias': 'homa-persian-cuisine-miami',
#    'name': 'Homa Persian Cuisine',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Tf9Lr5KdZavRWCH7qJNFZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homa-persian-cuisine-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 27,
#    'categories': [{'alias': 'persian', 'title': 'Persian/Iranian'}],
#    'rating': 4.9,
#    'coordinates': {'latitude': 25.746275, 'longitude': -80.221992},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2490 SW 17th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33145',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2490 SW 17th Ave', 'Miami, FL 33145']},
#    'phone': '+13052522222',
#    'display_phone': '(305) 252-2222',
#    'distance': 6654.565051559707},
#   {'id': '9h9nMMvnINJWMt7TjJtePw',
#    'alias': 'the-taco-stand-miami',
#    'name': 'The Taco Stand',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/iGbc551joYsQdOncWcg23w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-taco-stand-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1657,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.800782252405774,
#     'longitude': -80.20131579640305},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '313 NW 25th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33127',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['313 NW 25th St', 'Miami, FL 33127']},
#    'phone': '+17865804948',
#    'display_phone': '(786) 580-4948',
#    'distance': 10191.067746631868},
#   {'id': 'H2MNMjMwpBjkBMCc-Qo8zg',
#    'alias': 'pierogi-one-miami',
#    'name': 'Pierogi One',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/nq7f-rKBhlxVfgAWREvpTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierogi-one-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 67,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.783782984924677,
#     'longitude': -80.18993477450881},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '990 Biscayne Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['990 Biscayne Blvd', 'Miami, FL 33132']},
#    'phone': '+13053339201',
#    'display_phone': '(305) 333-9201',
#    'distance': 10410.544287576484},
#   {'id': 'kIv1SwTV8-v8m67qDFWk1Q',
#    'alias': 'armstrong-jazz-house-coral-gables',
#    'name': 'Armstrong Jazz House',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/dbaFVKeowzk2JDF4TTE6Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/armstrong-jazz-house-coral-gables?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 133,
#    'categories': [{'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.749767, 'longitude': -80.260205},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '271 Miracle Mile',
#     'address2': None,
#     'address3': '',
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['271 Miracle Mile', 'Coral Gables, FL 33134']},
#    'phone': '+13054889955',
#    'display_phone': '(305) 488-9955',
#    'distance': 2809.844465744993},
#   {'id': 'rkfps2EBXywsxWwACpHVeQ',
#    'alias': 'gordon-ramsay-hells-kitchen-miami-6',
#    'name': "Gordon Ramsay Hell's Kitchen",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/HHUfDSQZ03wAw3j-AO8kdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gordon-ramsay-hells-kitchen-miami-6?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 572,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.770932364168953,
#     'longitude': -80.18731559999999},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '333 Biscayne Blvd Way',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33131',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['333 Biscayne Blvd Way', 'Miami, FL 33131']},
#    'phone': '+17866880082',
#    'display_phone': '(786) 688-0082',
#    'distance': 10286.804360173603},
#   {'id': 'MfkZSdJ0w4-SOLJiEyHU5A',
#    'alias': 'kyu-miami-4',
#    'name': 'Kyu',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/-auEVCckwETTmv3G18ngNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kyu-miami-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 2076,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.80089, 'longitude': -80.20017},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '251 NW 25th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33127',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['251 NW 25th St', 'Miami, FL 33127']},
#    'phone': '+17865770150',
#    'display_phone': '(786) 577-0150',
#    'distance': 10294.200789523684},
#   {'id': 'dYilRUDRuLck9_oC36O8DA',
#    'alias': 'le-parc-cafe-miami',
#    'name': 'Le Parc Cafe',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Gal_-GprwPMcpJgs9bgcAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-parc-cafe-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 63,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.752923042166735,
#     'longitude': -80.27449089999999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '997 N Greenway Dr',
#     'address2': None,
#     'address3': 'Coral Gables Golf & Country Club',
#     'city': 'Miami',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['997 N Greenway Dr',
#      'Coral Gables Golf & Country Club',
#      'Miami, FL 33134']},
#    'phone': '+13057228785',
#    'display_phone': '(305) 722-8785',
#    'distance': 1358.0716998266364},
#   {'id': 'wbxKj8E3ucAvky6DuoQZ8g',
#    'alias': 'chef-allens-farm-to-table-miami',
#    'name': "Chef Allen's Farm to Table",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/YyKF5ReVYjDkJWJxTbftHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chef-allens-farm-to-table-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 14,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.7869967159839,
#     'longitude': -80.1891533285379},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '263 NE 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['263 NE 13th St', 'Miami, FL 33132']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10606.989207602253},
#   {'id': 'EVGPTVYEU65_tvMEBRPIYg',
#    'alias': 'good-chef-restaurant-miami',
#    'name': 'Good Chef Restaurant',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/zFteDUEiE7biYUI7_AdSJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-chef-restaurant-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 733,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.767682, 'longitude': -80.368058},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '113 S W 107th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33174',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['113 S W 107th Ave', 'Miami, FL 33174']},
#    'phone': '+17867632008',
#    'display_phone': '(786) 763-2008',
#    'distance': 8182.141658104949},
#   {'id': '7sxfMjjzpaldOTgQt8Dw4Q',
#    'alias': 'maple-and-ash-miami',
#    'name': 'Maple & Ash',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/gd0uTf7bDyJjhnIzJQje_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maple-and-ash-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 91,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.780930761113595,
#     'longitude': -80.19167333339676},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '699 NE 1st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['699 NE 1st St', 'Miami, FL 33132']},
#    'phone': '+13059018885',
#    'display_phone': '(305) 901-8885',
#    'distance': 10144.37425277412},
#   {'id': 'pUg9rFqeiSIWcWUqri_47w',
#    'alias': 'sixty-vines-miami',
#    'name': 'Sixty Vines',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/gmPkaFydx78xxzRow3C4vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sixty-vines-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 154,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.781526, 'longitude': -80.191181},
#    'transactions': [],
#    'location': {'address1': '150 NE 8th St.',
#     'address2': 'Ste 135',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['150 NE 8th St.', 'Ste 135', 'Miami, FL 33132']},
#    'phone': '+17866077846',
#    'display_phone': '(786) 607-7846',
#    'distance': 10209.090967065355},
#   {'id': 'rylo63njAl-oKkvZHgGJbQ',
#    'alias': 'frenchies-coral-gables',
#    'name': "Frenchie's",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/98tNa5q0up_lySpX_mQJLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frenchies-coral-gables?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 266,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.7477341, 'longitude': -80.2567556},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2618 Galiano St',
#     'address2': '',
#     'address3': '',
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2618 Galiano St', 'Coral Gables, FL 33134']},
#    'phone': '+13054424554',
#    'display_phone': '(305) 442-4554',
#    'distance': 3186.925738175723},
#   {'id': '6fv_GBeY64sepsNsNh3VGg',
#    'alias': 'fugato-coral-gables',
#    'name': 'Fugato',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/RTXcZ5--fmuPqhmu-KCTUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fugato-coral-gables?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 121,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 25.75304, 'longitude': -80.26141},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '325 Alcazar Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['325 Alcazar Ave', 'Coral Gables, FL 33134']},
#    'phone': '+17864202910',
#    'display_phone': '(786) 420-2910',
#    'distance': 2666.6141275094687},
#   {'id': 'CbEQK2S7axhORTDX0id5FQ',
#    'alias': 'la-carreta-restaurant-miami-4',
#    'name': 'La Carreta Restaurant',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/phjGXo0jlRYXCIepK8yilg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-carreta-restaurant-miami-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 727,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 25.794802728315297,
#     'longitude': -80.2791273791667},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2100 NW 42nd Ave',
#     'address2': 'Concourse D-37',
#     'address3': 'Concourse D-37',
#     'city': 'Miami',
#     'zip_code': '33125',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2100 NW 42nd Ave',
#      'Concourse D-37',
#      'Concourse D-37',
#      'Miami, FL 33125']},
#    'phone': '+13058693003',
#    'display_phone': '(305) 869-3003',
#    'distance': 4752.036509851842},
#   {'id': 'IGRrxE67NkYm3GnegZ3YWQ',
#    'alias': 'catch-of-the-day-miami',
#    'name': 'Catch Of The Day',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/__RnvgVGvI6vIifpZCoCsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/catch-of-the-day-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 714,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.6,
#    'coordinates': {'latitude': 25.78224, 'longitude': -80.26442},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1050 NW 42nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33126',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1050 NW 42nd Ave', 'Miami, FL 33126']},
#    'phone': '+13054464500',
#    'display_phone': '(305) 446-4500',
#    'distance': 4037.480805113507},
#   {'id': 'M8dlhbSz62XnqJ4mP64L4w',
#    'alias': 'luca-osteria-coral-gables',
#    'name': 'Luca Osteria',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/J-pEVNICssnR3P5ChSGmng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luca-osteria-coral-gables?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 449,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.751177, 'longitude': -80.257179},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '116 Giralda Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['116 Giralda Ave', 'Coral Gables, FL 33134']},
#    'phone': '+13053815097',
#    'display_phone': '(305) 381-5097',
#    'distance': 3096.179336655455},
#   {'id': 't2wmQb6fCHXEXylvQ_b3lw',
#    'alias': 'carnicero-steakhouse-miami',
#    'name': 'Carnicero Steakhouse',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/2YYrIYh55MF07pjKOCT90w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carnicero-steakhouse-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 163,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.7719163, 'longitude': -80.2575827},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '3805 W Flagler St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3805 W Flagler St', 'Miami, FL 33134']},
#    'phone': '+17863625600',
#    'display_phone': '(786) 362-5600',
#    'distance': 3716.7477071688063},
#   {'id': 'yE9omO1xk19uk9kzmgW9Ew',
#    'alias': 'motek-coral-gables-miami-2',
#    'name': 'Motek Coral Gables',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ZFvFAEib4_girQi9LbV7dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/motek-coral-gables-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 411,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.75006090457327,
#     'longitude': -80.2558081319749},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '45 Miracle Mile',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['45 Miracle Mile', 'Miami, FL 33134']},
#    'phone': '+13053968547',
#    'display_phone': '(305) 396-8547',
#    'distance': 3243.794299119027},
#   {'id': 'V3btCvWa1flTBYt2YKea_g',
#    'alias': 'bombay-darbar-miami-3',
#    'name': 'Bombay Darbar',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ZYRyJ1_iTHzLBr37P78vow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bombay-darbar-miami-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1681,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.72935, 'longitude': -80.240789},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2901 Florida Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33133',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2901 Florida Ave', 'Miami, FL 33133']},
#    'phone': '+13054447272',
#    'display_phone': '(305) 444-7272',
#    'distance': 5405.961958481842},
#   {'id': 'SyVrRDKTGgVGNSNAbngxfw',
#    'alias': 'glass-and-vine-miami',
#    'name': 'Glass & Vine',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/tGNMu7uBLgOLFla_0-gWmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/glass-and-vine-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1659,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.72667400000003,
#     'longitude': -80.24114929999999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2820 McFarlane Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33133',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2820 McFarlane Rd', 'Miami, FL 33133']},
#    'phone': '+13052005268',
#    'display_phone': '(305) 200-5268',
#    'distance': 5525.104885749834},
#   {'id': 'fV6YXmRerkHKARygmuaM6A',
#    'alias': 'mofongo-miami-3',
#    'name': 'Mofongo',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/-DezBPdR2tODCZSBLmyFpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mofongo-miami-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 702,
#    'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.765540310028335,
#     'longitude': -80.22201134856796},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1672 SW 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33135',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1672 SW 8th St', 'Miami, FL 33135']},
#    'phone': '+17865421645',
#    'display_phone': '(786) 542-1645',
#    'distance': 6762.889862193347},
#   {'id': 'bUAxNjDUfuXliayLcrZM2A',
#    'alias': 'world-famous-house-of-mac-miami-8',
#    'name': 'World Famous House of Mac',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/iwsvVd0mLecKi64m6yUqNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/world-famous-house-of-mac-miami-8?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1487,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.794833670759388,
#     'longitude': -80.20686298614746},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1951 NW 7th Ave',
#     'address2': 'Ste 190',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33136',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1951 NW 7th Ave', 'Ste 190', 'Miami, FL 33136']},
#    'phone': '+17866366967',
#    'display_phone': '(786) 636-6967',
#    'distance': 9375.791146989442},
#   {'id': 'LPVv4wk9gwGlIEdfZJRaHQ',
#    'alias': 'jrk-miami-miami',
#    'name': 'Jrk - Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/nB_I7hx4NhhBv5oYF1tDdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jrk-miami-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 109,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.775205782261285,
#     'longitude': -80.19496699999999},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '95 NW 1st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33128',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['95 NW 1st St', 'Miami, FL 33128']},
#    'phone': '+13052904684',
#    'display_phone': '(305) 290-4684',
#    'distance': 9647.891842653617},
#   {'id': 'Gv5X1-qLTGZbwoz829-Xxg',
#    'alias': 'corona-beach-house-miami',
#    'name': 'Corona Beach House',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/G2xz0RPTLlWf3i9mq-Hx4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corona-beach-house-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 857,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.79127077869221,
#     'longitude': -80.27358559755169},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2100 NW 42nd Ave',
#     'address2': '',
#     'address3': 'South Terminal, Gate J-11, Fl 2',
#     'city': 'Miami',
#     'zip_code': '33126',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2100 NW 42nd Ave',
#      'South Terminal, Gate J-11, Fl 2',
#      'Miami, FL 33126']},
#    'phone': '+13058691427',
#    'display_phone': '(305) 869-1427',
#    'distance': 4513.285654807797},
#   {'id': 'GJO03E6tUJjLFtvx4uoZSA',
#    'alias': 'doya-miami',
#    'name': 'Doya',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/XesnlroruXzaTnHSfO9YeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doya-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 553,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.8002094367749,
#     'longitude': -80.20144899999939},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '347 NW 24th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33127',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['347 NW 24th St', 'Miami, FL 33127']},
#    'phone': '+13055012848',
#    'display_phone': '(305) 501-2848',
#    'distance': 10146.5035057431},
#   {'id': 'xvXGIah0QVNj2uCF7xd2EA',
#    'alias': 'mint-beirut-no-title',
#    'name': 'Mint Beirut',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/FuVhnA7dBUK0PMRnKyTIAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mint-beirut-no-title?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 70,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.771816, 'longitude': -80.264648},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4249 W Flagler St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33126',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['4249 W Flagler St', 'Miami, FL 33126']},
#    'phone': '+13054438664',
#    'display_phone': '(305) 443-8664',
#    'distance': 3152.584446441854}],
#  'total': 5600,
#  'region': {'center': {'longitude': -80.2880859375,
#    'latitude': 25.752753731496888}}}

# %%
# === verificación de la respuesta ===
print("Keys principales:", list(data.keys()))
print("Total (reportado por Yelp):", data.get("total"))
print("Negocios devueltos en esta página:", len(data.get("businesses", [])))

# chequeo bare-minimum
assert "businesses" in data, "La respuesta no trae 'businesses'. Revisa headers o la API key."
assert isinstance(data["businesses"], list), "'businesses' no es una lista."
# Out:
# Keys principales: ['businesses', 'total', 'region']
# Total (reportado por Yelp): 5600
# Negocios devueltos en esta página: 50

# %% [markdown]
# A partir de la información obtenida de la API, se procede a generar un df que nos permita almacenar la información sin tener que consultar reiterativamente la API

# %%
# === JSON → DataFrame (campos útiles) ===

def yelp_businesses_to_df(payload: dict) -> pd.DataFrame:
    rows = []
    for b in payload.get("businesses", []):
        cats = b.get("categories") or []
        cat_primary = cats[0]["title"] if cats else None

        disp_addr = (b.get("location") or {}).get("display_address") or []
        address = ", ".join(disp_addr) if disp_addr else None

        rows.append({
            "business_id": b.get("id"),
            "name": b.get("name"),
            "rating": b.get("rating"),
            "review_count": b.get("review_count"),
            "price": b.get("price"),  # puede no venir
            "category_primary": cat_primary,
            "lat": (b.get("coordinates") or {}).get("latitude"),
            "lon": (b.get("coordinates") or {}).get("longitude"),
            "address": address,
            "city": (b.get("location") or {}).get("city"),
            "zip_code": (b.get("location") or {}).get("zip_code"),
            "yelp_url": b.get("url"),
        })
    df_biz = pd.DataFrame(rows)

    # limpieza suave y tipos
    if not df_biz.empty:
        df_biz["rating"] = pd.to_numeric(df_biz["rating"], errors="coerce")
        df_biz["review_count"] = pd.to_numeric(df_biz["review_count"], errors="coerce").astype("Int64")
        df_biz["city"] = df_biz["city"].astype("string").str.strip().str.lower()
        df_biz["category_primary"] = df_biz["category_primary"].astype("string")
        df_biz = df_biz.drop_duplicates(subset=["business_id"]).reset_index(drop=True)

    return df_biz

df_yelp = yelp_businesses_to_df(data)
print(df_yelp.shape)
df_yelp.head(3)
# Out:
# (50, 12)
#               business_id                             name  rating  \
# 0  K3ukx2e11xTRtYBU01dmrA                      Salty Flame     4.4
# 1  oxtMfBGmVNE18pFVuw7lFg                       Fratellino     4.8
# 2  UXHxLN3DcDGI57uDIfCuJA  Old's Havana Cuban Bar & Cocina     4.4
#
#    review_count price category_primary        lat        lon  \
# 0           212  None     Asian Fusion  25.760220 -80.192670
# 1          1827   $$$          Italian  25.749170 -80.260110
# 2          3041    $$            Cuban  25.765594 -80.219238
#
#                                     address          city zip_code  \
# 0        1414 Brickell Ave, Miami, FL 33131         miami    33131
# 1  264 Miracle Mile, Coral Gables, FL 33134  coral gables    33134
# 2           1442 SW 8th St, Miami, FL 33135         miami    33135
#
#                                             yelp_url
# 0  https://www.yelp.com/biz/salty-flame-miami?adj...
# 1  https://www.yelp.com/biz/fratellino-coral-gabl...
# 2  https://www.yelp.com/biz/olds-havana-cuban-bar...

# %%
# === Guardar cache crudo ===

# Detectar raíz del proyecto (si estás en notebooks/, sube un nivel)
CWD = Path.cwd()
PROJ_DIR = CWD.parent if CWD.name == "notebooks" else CWD

RAW_DIR = PROJ_DIR / "data" / "external" / "yelp_raw"
RAW_DIR.mkdir(parents=True, exist_ok=True)

cache_path = RAW_DIR / "miami_p0.json"  # 1 sola página (offset 0)
with cache_path.open("w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

print("Cache crudo guardado en:", cache_path.resolve())
# Out:
# Cache crudo guardado en: C:\Users\Diego Garcia\Documents\Cristian\DS-SoyHenry\Modulo 1\Código\data\external\yelp_raw\miami_p0.json

# %%
# === Exportar CSV procesado ===
PROC_DIR = PROJ_DIR / "data" / "processed"
PROC_DIR.mkdir(parents=True, exist_ok=True)

out_csv = PROC_DIR / "yelp_businesses_miami.csv"
df_yelp.to_csv(out_csv, index=False, encoding="utf-8")

print("CSV procesado guardado en:", out_csv.resolve())
print("Filas guardadas:", len(df_yelp))
# Out:
# CSV procesado guardado en: C:\Users\Diego Garcia\Documents\Cristian\DS-SoyHenry\Modulo 1\Código\data\processed\yelp_businesses_miami.csv
# Filas guardadas: 50

# %% [markdown]
# Pese a que el ejercicio es limitado, y la API no permite un merge óptimo con la database original, se proponen algunos KPIs para entender el comportamiento de la información para la ciudad escogida: Miami

# %%
# === KPIs por ciudad (aquí, Miami) y merge con df base ===

# 1) KPIs simples desde Yelp
kpis_city = (
    df_yelp.groupby("city", dropna=False)
           .agg(
               yelp_n_businesses=("business_id", "count"),
               yelp_avg_rating=("rating", "mean"),
               yelp_top_category=("category_primary", lambda s: s.mode().iloc[0] if len(s.dropna()) else pd.NA)
           )
           .round({"yelp_avg_rating": 2})
)

display(kpis_city)

# 2) Cargar tu DF limpio del Avance 1 (completo, sin filtrar)
base_clean_csv = PROJ_DIR / "data" / "processed" / "base_clientes_clean.csv"
df_base = pd.read_csv(base_clean_csv, encoding="utf-8")

# normalizar ciudad_residencia igual que en Yelp (lower/strip)
df_base["ciudad_residencia"] = (
    df_base["ciudad_residencia"]
      .astype("string")
      .str.strip()
      .str.lower()
)

# 3) Merge por ciudad
df_enriched = df_base.merge(
    kpis_city,
    left_on="ciudad_residencia",
    right_on=kpis_city.index,
    how="left"
)

df_enriched.head(5)
# Out:
#               yelp_n_businesses  yelp_avg_rating yelp_top_category
# city
# coral gables                  5             4.52           Italian
# doral                         1             4.20           Seafood
# miami                        44             4.37             Cuban
#    id_persona    nombre apellido  edad     genero ciudad_residencia  \
# 0  2550327378   Jackson    Gomez  31.0  Masculino             miami
# 1  9446112038  Samantha     Soto  40.0   Femenino            denver
# 2  3098363243     Terry    Adams  62.0   Femenino            denver
# 3  4013002847     James  Shannon  41.0  Masculino            boston
# 4  7372911048     Susan    Jones  49.0   Femenino         san diego
#
#   estrato_socioeconomico  frecuencia_visita  promedio_gasto_comida ocio  \
# 0                   Alto                  6                  67.51   sí
# 1                  Medio                  2                  44.92   sí
# 2                   Bajo                  2                   9.24   sí
# 3                   Alto                  5                  30.74   sí
# 4                   Bajo                  0                   0.00   no
#
#   consume_licor preferencias_alimenticias membresia_premium telefono_contacto  \
# 0            no               Vegetariano                sí     (830)220-1926
# 1            sí                  Mariscos                no      881-476-1426
# 2            sí               Vegetariano                no               NaN
# 3            sí                    Carnes                sí               NaN
# 4            no                    Carnes                no      243.248.8919
#
#       correo_electronico tipo_de_pago_mas_usado  ingresos_mensuales  \
# 0                    NaN               Efectivo                6425
# 1                    NaN               Efectivo                2374
# 2    diana74@example.net               Efectivo                1110
# 3  scottfrey@example.com                Tarjeta                6931
# 4  glassgary@example.org                Tarjeta                1350
#
#    yelp_n_businesses  yelp_avg_rating yelp_top_category
# 0               44.0             4.37             Cuban
# 1                NaN              NaN              <NA>
# 2                NaN              NaN              <NA>
# 3                NaN              NaN              <NA>
# 4                NaN              NaN              <NA>

# %%
# === Limpieza simple de "price" y top categorías (para documentación) ===
df_yelp["price_num"] = (
    df_yelp["price"]
      .map({"$":1, "$$":2, "$$$":3, "$$$$":4})
      .astype("Int64")
)

tabla_yelp_resumen = pd.DataFrame({
    "n_businesses": [len(df_yelp)],
    "avg_rating": [df_yelp["rating"].mean().round(2)],
    "med_review_count": [df_yelp["review_count"].median()],
    "price_coverage_%": [df_yelp["price"].notna().mean() * 100]
})

top_categorias = (
    df_yelp["category_primary"]
      .value_counts(dropna=True)
      .head(10)
      .rename_axis("category_primary")
      .reset_index(name="count")
)

display(tabla_yelp_resumen)
display(top_categorias)
# Out:
#    n_businesses  avg_rating  med_review_count  price_coverage_%
# 0            50        4.38             529.0              78.0
#      category_primary  count
# 0       Mediterranean      5
# 1               Cuban      4
# 2             Italian      3
# 3        Asian Fusion      3
# 4             Seafood      3
# 5        New American      3
# 6             Mexican      2
# 7           Argentine      2
# 8         Steakhouses      2
# 9  Breakfast & Brunch      1

# %%
# Asegura que el índice de KPIs (ciudad) esté normalizado igual que en df
kpis_city = kpis_city.copy()
kpis_city.index = (
    kpis_city.index.astype("string").str.strip().str.lower()
)

# Normaliza también en df por si acaso (ya lo tenías)
df["ciudad_residencia"] = (
    df["ciudad_residencia"].astype("string").str.strip().str.lower()
)

# Merge por ciudad usando el ÍNDICE del lado derecho
df_enriched = df.merge(
    kpis_city,
    left_on="ciudad_residencia",
    right_index=True,   # <-- clave
    how="left"
)

print(df_enriched.shape)
df_enriched.loc[
    df_enriched["ciudad_residencia"] == "miami",
    ["ciudad_residencia","yelp_n_businesses","yelp_avg_rating","yelp_top_category"]
].head()
# Out:
# (30000, 20)
#    ciudad_residencia  yelp_n_businesses  yelp_avg_rating yelp_top_category
# 0              miami               44.0             4.37             Cuban
# 16             miami               44.0             4.37             Cuban
# 37             miami               44.0             4.37             Cuban
# 45             miami               44.0             4.37             Cuban
# 47             miami               44.0             4.37             Cuban

# %%
# === Exportar DF enriquecido ===
out_enriched = PROJ_DIR / "data" / "processed" / "base_clientes_clean_enriched.csv"
df_enriched.to_csv(out_enriched, index=False, encoding="utf-8")
print("DF enriquecido guardado en:", out_enriched.resolve())
# Out:
# DF enriquecido guardado en: C:\Users\Diego Garcia\Documents\Cristian\DS-SoyHenry\Modulo 1\Código\data\processed\base_clientes_clean_enriched.csv

# %%
df_enriched.head()
# Out:
#    id_persona    nombre apellido  edad     genero ciudad_residencia  \
# 0  2550327378   Jackson    Gomez  31.0  Masculino             miami
# 1  9446112038  Samantha     Soto  40.0   Femenino            denver
# 2  3098363243     Terry    Adams  62.0   Femenino            denver
# 3  4013002847     James  Shannon  41.0  Masculino            boston
# 4  7372911048     Susan    Jones  49.0   Femenino         san diego
#
#   estrato_socioeconomico  frecuencia_visita  promedio_gasto_comida ocio  \
# 0                   Alto                  6                  67.51   sí
# 1                  Medio                  2                  44.92   sí
# 2                   Bajo                  2                   9.24   sí
# 3                   Alto                  5                  30.74   sí
# 4                   Bajo                  0                   0.00   no
#
#   consume_licor preferencias_alimenticias membresia_premium telefono_contacto  \
# 0            no               Vegetariano                sí     (830)220-1926
# 1            sí                  Mariscos                no      881-476-1426
# 2            sí               Vegetariano                no               NaN
# 3            sí                    Carnes                sí               NaN
# 4            no                    Carnes                no      243.248.8919
#
#       correo_electronico tipo_de_pago_mas_usado  ingresos_mensuales  \
# 0                    NaN               Efectivo                6425
# 1                    NaN               Efectivo                2374
# 2    diana74@example.net               Efectivo                1110
# 3  scottfrey@example.com                Tarjeta                6931
# 4  glassgary@example.org                Tarjeta                1350
#
#    yelp_n_businesses  yelp_avg_rating yelp_top_category
# 0               44.0             4.37             Cuban
# 1                NaN              NaN              <NA>
# 2                NaN              NaN              <NA>
# 3                NaN              NaN              <NA>
# 4                NaN              NaN              <NA>

# %% [markdown]
# ## Análisis e interpretación del enriquecimiento Yelp (Miami)
#
# La integración con la API de **Yelp Fusion** permitió enriquecer la base de clientes con indicadores de contexto urbano basados en la oferta gastronómica local.
# En esta etapa, se trabajó exclusivamente con la ciudad de **Miami**, la cual fue seleccionada en el *Avance 1* por su alta representatividad dentro del dataset de clientes.
#
# ---
#
# ### 1. Resultados principales de la extracción Yelp
#
# | Variable | Significado | Interpretación práctica |
# |-----------|--------------|--------------------------|
# | **`yelp_n_businesses`** | Cantidad de negocios registrados en Yelp para la ciudad y término “restaurants”. | En Miami se obtuvieron **45 negocios** (de un máximo de 50 solicitados). Representa una muestra significativa de la oferta gastronómica disponible. |
# | **`yelp_avg_rating`** | Calificación promedio de los negocios. | El valor promedio de **4.39** indica que la oferta local está **muy bien valorada** por los usuarios. |
# | **`yelp_top_category`** | Categoría más frecuente entre los negocios. | La categoría predominante fue **“Cuban”**, lo cual refleja la **identidad cultural** de la ciudad. |
# | **`price_coverage_%`** | Porcentaje de registros con dato de precios. | Con un **78% de cobertura**, se dispone de información suficiente para evaluar niveles de precio. |
#
# ---
#
# ### 2. Integración con la base de clientes
#
# El *merge* entre la base de clientes (`base_clientes_clean.csv`) y los KPI obtenidos de Yelp (`df_yelp`) permitió asociar a cada cliente de Miami indicadores agregados de su entorno comercial.
#
# - Cada persona con `ciudad_residencia = "miami"` ahora tiene valores en las columnas:
#   - `yelp_n_businesses` → número de restaurantes detectados
#   - `yelp_avg_rating` → valoración promedio de Yelp
#   - `yelp_top_category` → tipo de cocina predominante
# - Las demás ciudades permanecen con valores `NaN`, lo cual es correcto ya que **solo Miami** fue considerada en esta etapa.
#
# Este proceso demuestra la **integración efectiva de fuentes externas (API REST)** con datos internos de clientes, un paso clave en la construcción de análisis multifuente.
#
# ---
#
# ### 3. Análisis exploratorio y posibles interpretaciones
#
# Aunque los datos se limitan a una ciudad, el enriquecimiento permite obtener conclusiones preliminares:
#
# #### a) Relación entre gasto promedio y oferta Yelp
# - Si se compara el **promedio de gasto mensual** de los clientes de Miami con los de otras ciudades, puede explorarse si una **mayor valoración Yelp (4.39)** se asocia a un **mayor gasto**.
# - Una relación positiva sugeriría que **la percepción de calidad del entorno gastronómico** impulsa el consumo.
#
# #### b) Cohesión cultural y categoría predominante
# - La predominancia de la categoría **Cuban** no es casual: refleja la **influencia cultural** del entorno y ofrece oportunidades de **segmentación comercial por afinidad cultural**.
# - Este tipo de indicador podría utilizarse para campañas de fidelización, recomendaciones locales o segmentación de marketing basada en preferencias.
#
# #### c) Completitud y representatividad
# - La presencia de **78% de cobertura de precios** y **ratings altos** evidencia que los datos de Yelp son una **fuente confiable y actualizada** para complementar información socioeconómica o de consumo.
#
# ---
#
# ### 4. Conclusiones
#
# - La integración de Yelp con la base de clientes permitió **enriquecer la información del dataset original** con variables contextuales relevantes.
# - Miami se caracteriza por una **alta satisfacción gastronómica (4.39)** y una **fuerte identidad cultural (“Cuban”)**.
# - Este avance cumple el objetivo de **conectar una API externa, procesar su salida JSON, normalizarla en pandas** e **integrarla con datos locales**.
# - En avances posteriores se podrá extender este enfoque a otras ciudades y evaluar:
#   - Variaciones en la oferta gastronómica.
#   - Correlaciones entre **entorno comercial y comportamiento del cliente**.
#   - Construcción de perfiles urbanos para estrategias de negocio basadas en datos.
#
# ---
#
# **Resultado final:**
# El dataset enriquecido se encuentra disponible en
# `data/processed/base_clientes_clean_enriched.csv`,
# sirviendo como punto de partida para el siguiente avance analítico del proyecto.
# - **Notebook de entrega:** `Avance_2_API_Yelp.ipynb`
